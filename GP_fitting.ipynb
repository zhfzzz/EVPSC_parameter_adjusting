# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.gaussian_process as gp

# %%
data_source = pd.read_csv('MIGA2.csv')

# %%
best_fit = np.array([150,9,110,125,47,6,8,100,150,100,3000,0.9348160127544503,0.9660144508627793,0.9747496972180452,0.9682134798104164,0.9315057362704031,0.9669828970913715,0.945189905610238,0.955353168516815,0.000001])
data_source.loc[149]=best_fit

# %%
train_X = data_source.iloc[30:][['tau_0_bas','tau_0_pris','tau_0_pyr','tau_0_twin','tau_1_bas','tau_1_pris','tau_1_pyr','theta_0_bas','theta_0_pris','theta_0_pyr']].to_numpy()
train_Y = data_source.iloc[30:]['mean_R2'].to_numpy()
test_X = data_source.iloc[0:30][['tau_0_bas','tau_0_pris','tau_0_pyr','tau_0_twin','tau_1_bas','tau_1_pris','tau_1_pyr','theta_0_bas','theta_0_pris','theta_0_pyr']].to_numpy()
test_Y = data_source.iloc[0:30]['mean_R2'].to_numpy()

# %%
kernel = gp.kernels.RBF(1.0,1.0)
model = gp.GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=0.1, normalize_y=True)

# %%
model.fit(train_X,train_Y.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-2c9250297d17> in <module>
# ----> 1 model.fit(train_X,train_Y.reshape(-1,1))
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/gaussian_process/_gpr.py in fit(self, X, y)
#     235             optima = [(self._constrained_optimization(obj_func,
#     236                                                       self.kernel_.theta,
# --> 237                                                       self.kernel_.bounds))]
#     238
#     239             # Additional runs are performed from log-uniform chosen initial
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/gaussian_process/_gpr.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     506             opt_res = scipy.optimize.minimize(
#     507                 obj_func, initial_theta, method="L-BFGS-B", jac=True,
# ...

# %%
train_X.shape
# Out:
# (120, 10)
